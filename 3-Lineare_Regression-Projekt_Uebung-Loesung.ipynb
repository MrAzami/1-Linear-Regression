# %% [markdown]
# # Lineare Regression - Projekt Übung - Lösung
#
# Glückwunsch, du hast deinen ersten Auftrag mit einer Ecommerce Firma aus New York erhalten. Diese Firma verkauft online Kleidung bietet aber auch Kleidungs- und Styleberatungen in Läden an. Kunden können in den Laden kommen, sich mit einem Stylisten beraten und anschließend per App oder Webseite die Kleidung kaufen, die sie möchten.
#
# Die Firma ist gerade dabei zu entscheiden, ob sie ihren Fokus lieber auf die App oder die Webseite legen sollen. Dein Job ist es sie bei dieser Entscheidung zu unterstützen. Los geht's!
#
# Folge den Anweisungen, um die Kundendaten zu analysieren (selbstverständlich ohne echte Kreditkartennummern und E-Mail-Adressen).

# %% [markdown]
# ## Imports
#
# **Importiere pandas, numpy, matplotlib und seaborn. Setze außerdem %matplotlib inline.**

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: matplotlib in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/ramazansarikaya/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Erhalte die Daten
#
# Wir arbeiten mit der "Ecommerce Customers" CSV-Datei von der Firma. Sie beinhaltet Informationen wie E-Mail-Adressen, Addressen usw. Außerdem haben wir numerische Werte in folgenden Spalten vorliegen:
#
# * Avg. Session Length: Durchschnittliche Länge einer Style beratung im Laden.
# * Time on App: Durchschnittlich verbrachte Zeit in der App in Minuten.
# * Time on Website: Durchschnittlich verbrachte Zeit auf der Homepage in Minuten.
# * Length of Membership: Anzahl der Jahre die ein Kunde bereits Mitglied ist.
#
# **Lese die "Ecommerce Customers" CSV-Datei als DataFrame namens "customers" ein.**

# %%
customers = pd.read_csv("Ecommerce_Customers")

# %% [markdown]
# **Schaue dir den Head von customers an und wende die info() und describe() Methode an.**

# %%
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ## Explorative Daten Analyse
#
# **Nehmen wir die Daten unter die Lupe!**
#
# Für den Rest der Übung werden wir nur die numerischen Dten in der CSV-Datei verwenden.
# ___
#
# **Nutze Seaborn um ein jointplot zu erstellen, um die Zeit auf der Webseite (en. Time on Website) und die jährliche ausgegebene Summe (en. Yearly Amount Spent) zu vergleichen. Ergibt die Korrelation Sinn?**

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
import scipy.stats as stats

# Je mehr Zeit auf der Webseite, desto mehr Ausgaben
r, p = stats.pearsonr(customers['Time on Website'], customers['Yearly Amount Spent'])
jp = sns.jointplot(x='Time on Website',y='Yearly Amount Spent',data=customers)
pos, = jp.ax_joint.plot([], [], linestyle="", alpha=0)
jp.ax_joint.legend([pos], ['pearsonr={:.4f}, p={:.2f}'.format(r, p)])
plt.show()

# %% [markdown]
# **Wiederhole das gleiche für die Zeit in der App (en. Time on App).**

# %%
r, p = stats.pearsonr(customers['Time on App'], customers['Yearly Amount Spent'])
jp = sns.jointplot(x='Time on App',y='Yearly Amount Spent',data=customers)
pos, = jp.ax_joint.plot([], [], linestyle="", alpha=0)
jp.ax_joint.legend([pos], ['pearsonr={:.1f}, p={:.5f}'.format(r, p)])

# %% [markdown]
# **Erstelle jetzt mit jointplot ein 2D Hex Bin Plot, das die Zeit in der App und die Länge der Mitgliedschaft (en. Length of Membership) vergleicht.**

# %%
sns.jointplot(x='Time on App',y='Length of Membership',kind='hex',data=customers)

# %% [markdown]
# **Untersuchen wir diese Art von Beziehung für den ganzen Datensatz. Erstelle mit pairplot das nachfolgende Diagramm.**

# %%
sns.pairplot(customers)

# %% [markdown]
# **Anhand dieser Grafik: Was scheint am meisten mit den jährlichen Ausgaben zu korrelieren?**

# %%
# Die Länge der Mitgliedschaft

# %% [markdown]
# **Erstelle ein linear model plot (mit Hilfe von searborn's lmplot) von jährlichen Ausgaben vs. Länge der Mitgliedschaft.**

# %%
sns.lmplot(x='Length of Membership',y='Yearly Amount Spent',data=customers)

# %% [markdown]
# ## Trainings- und Testdaten
#
# Jetzt wo wir unsere Daten ein wenig untersucht haben können wir fortschreiten und Daten in Trainings- und Testdaten aufteilen.
#
# **Setze eine Variable X gleich den numerischen Features der Kunden und eine Variable Y gleich der "Yearly Amount Spent" Spalte.**

# %%
y = customers['Yearly Amount Spent']

# %%
X = customers[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]

# %% [markdown]
# **Nutze model_selection.train_test_split aus sklearn, um die Daten in Trainings- und Testdaten zu trennen. Setze dabei test_size=0.3 und random_state=101.**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Das Modell trainieren
#
# Als nächstes können wir unser Modell mit den Trainingsdaten trainieren!
#
# **Importiere LinearRegression aus sklearn.linear_model.**

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Erstelle eine Instanz von LinearRegression() namens lm.**

# %%
lm = LinearRegression() # lm als Variable, Abkürzung für Linear Modell

# %% [markdown]
# **Trainiere lm mit den Trainingsdaten.**

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(X_train.head)
print(y_train.head)
# Out:
# <bound method NDFrame.head of      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 202            31.525752    11.340036        37.039514              3.811248
# 428            31.862741    14.039867        37.022269              3.738225
# 392            33.258238    11.514949        37.128039              4.662845
# 86             33.877779    12.517666        37.151921              2.669942
# 443            33.025020    12.504220        37.645839              4.051382
# ..                   ...          ...              ...                   ...
# 63             32.789773    11.670066        37.408748              3.414688
# 326            33.217188    10.999684        38.442767              4.243813
# 337            31.827979    12.461147        37.428997              2.974737
# 11             33.879361    11.584783        37.087926              3.713209
# 351            32.189845    11.386776        38.197483              4.808320
#
# [350 rows x 4 columns]>
# <bound method NDFrame.head of 202    443.965627
# 428    556.298141
# 392    549.131573
# 86     487.379306
# 443    561.516532
#           ...
# 63     483.159721
# 326    505.230068
# 337    440.002748
# 11     522.337405
# 351    533.396554
# Name: Yearly Amount Spent, Length: 350, dtype: float64>

# %% [markdown]
# **Gebe die Koeffizienten des Modells aus.**

# %%
# Die Koeffizienten
print('Coefficients: \n', lm.coef_)

# fx = lm.coef[0] * spalte0 + lm.coef[1] * spalte1 + lm.coef[2] * spalte2 + lm.coef[3] * spalte3 + lm.intercept_
# Out:
# Coefficients:
#  [25.98154972 38.59015875  0.19040528 61.27909654]

# %% [markdown]
# ## Testdaten voraussagen
#
# Nachdem wir unser Modell trainiert haben können wir seine Güte mit den Testdaten überprüfen.
#
# **Nutze lm.predict(), um die X_test Daten vorherzusagen.**

# %%
predictions = lm.predict(X_test)

# %% [markdown]
# **Erstelle ein Scatterplot mit den echten Testwerten im vergleich zu den vorhergesagten.**

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# ## Das Modell bewerten
#
# Lass uns unser Modell indem wir die Residual Sum of Squares und die erklärte Varianz (R^2) ausrechnen.
#
# **Berechne MAE, MSE und RMSE.**
#
# *Hinweis: Die Lektion zur linearen Regression verrät dir mehr zu den Werten.*

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 7.228148653430815
# MSE: 79.81305165097409
# RMSE: 8.933815066978614

# %% [markdown]
# ## Residuen
#
# Du solltest ein sehr gutes Modell mit einem guten Modelfit erhalten haben. Lass uns schnell noch die Residuen untersuchen, um sicher zu gehen, dass alles mit unseren Daten okay war.
#
# **Erstelle ein Histogramm der Residuen und gehe sicher, dass es normalverteilt aussieht. Nutze entweder searborn histplot oder einfach plt.hist().**

# %%
sns.histplot((y_test-predictions),bins=15, kde=True)
# Out:
# <Axes: xlabel='Yearly Amount Spent', ylabel='Count'>

# %% [markdown]
# ## Schlussfolgerungen
#
# Wir wollen immer noch die ursprüngliche Fragestellung beantworten: sollten wir unsern Fokus auf die App oder die Webseite legen? Oder ggf. spielt das gar keine große Rolle und die Jahre der Mitgliedschaft sind wirklich ausschlaggebend. Schauen wir dazu nach, ob wir die Koeffizienten interpretieren können.
#
# **Baue den dargestellten DataFrame nach.**

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                       Coeffecient
# Avg. Session Length     25.981550
# Time on App             38.590159
# Time on Website          0.190405
# Length of Membership    61.279097

# %% [markdown]
# **Wie kannst du diese Koeffizienten interpretieren?**
#
# Interpretation der Koeffizienten:
#
# * Halten wir alle anderen Werte konstant dann führt ein Anstieg in **Avg. Session Length** um 1 Einheit zu einem Anstieg von 25.98 an ausgegebenen Dollars.
# * Halten wir alle anderen Werte konstant dann führt ein Anstieg in **Time on App** um 1 Einheit zu einem Anstieg von 38.59 an ausgegebenen Dollars.
# * Halten wir alle anderen Werte konstant dann führt ein Anstieg in **Time on Website** um 1 Einheit zu einem Anstieg von 0.19 an ausgegebenen Dollars.
# * Halten wir alle anderen Werte konstant dann führt ein Anstieg in **Length of Membership** um 1 Einheit zu einem Anstieg von 61.27 an ausgegebenen Dollars.

# %% [markdown]
# **Denkst du die Firma sollte sich eher auf die App oder die Webseite fokusieren?**
#
# Die Frage ist gar nicht so leicht zu beantworten. Es gibt zwei betrachtungsweisen: Entwickle eine bessere Webseite, um zur App aufzuschließen. Oder baue die App aus, da sie stand jetzt besser funktioniert. Die finale Antwort hängt noch von weiteren Faktoren ab, die wir aus diesen Daten nicht direkt ablesen können. Wir bräuchten weitere Informationen vom Kunden. Weitere Ansatzpunkte könnten außerdem eine Untersuchung zwischen dem Zusammenhang zwischen Länge der Mitgliedschaft und der Webseite bzw. der App sein.
#
# # Gut gemacht!
#
# Glückwunsch zur Erfüllung deines ersten Auftrags! Die Firma war sehr dankbar für die Einblicke. Weiter geht's!
